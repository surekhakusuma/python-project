# %%
# import Homepage2
import time
from tkinter import *
import os
import tkinter as tk 
from tkinter import ttk 
from PIL import ImageTk,Image

global root
root = Tk()
import mysql.connector
con=mysql.connector.connect(host="localhost",user="root",passwd="Surekha@1",database = 'health2')
mcrs=con.cursor()
#mcrs.execute("create database health2")

import Homepage2_support

def open_health_test():
    root.deiconify()
#     top.destroy()
    health_testgui=health_test(root)


def contact_us():
    global contact_us_scrren
    contact_us_scrren = Toplevel(root)
    contact_us_scrren.title('CONTACT US')
    l2 = tk.Label(contact_us_scrren)
    l2.pack()        
    l2.configure(background="#ffffdf")
    l2.configure(disabledforeground="#a3a3a3")
    l2.configure(foreground="#000000")
    l2.configure(text = '''Postal Address:
Lovely Professional University, Jalandhar - 
Delhi G.T. Road, Phagwara, Punjab (India) - 144411
Phone: +91-1824-517000
Phone: +91-1824-404404
Toll Free: 1800 274 0615
Toll Free: 1800 102 4431
WhatsApp Chat: +91 98525 69000
''')
    
def Help():
    global help_scrren
    help_scrren = Toplevel(root)
    help_scrren.title('HELP')
    l2 = tk.Label(help_scrren)
    l2.pack()        
    l2.configure(background="#ffffdf")
    l2.configure(disabledforeground="#a3a3a3")
    l2.configure(foreground="#000000")
    l2.configure(text = '''For any queries please see the project report
still curious??
Please contact us''')
    

def vp_start_gui():
    '''Starting point when module is the main routine.'''
    
    global val, w
    root = tk.Tk()
    Homepage2_support.set_Tk_var()
    global top
    t = Toplevel1 (root)
#     Homepage2_support.init(root, top)
    root.mainloop()

w = None
def create_Toplevel1(rt, *args, **kwargs):
    '''Starting point when module is imported by another module.
       Correct form of call: 'create_Toplevel1(root, *args, **kwargs)' .'''
    global w, w_win, root
    #rt = root
    root = rt
    w = tk.Toplevel (root)
    Homepage2_support.set_Tk_var()
    t = Toplevel1 (w)
    Homepage2_support.init(w, top, *args, **kwargs)
    return (w, top)

def destroy_Toplevel1():
    global w
    w.destroy()
    w = None

class Toplevel1:
    def __init__(self, top=None):
        '''This class configures and populates the toplevel window.
           top is the toplevel containing window.'''
        _bgcolor = '#d9d9d9'  # X11 color: 'gray85'
        _fgcolor = '#000000'  # X11 color: 'black'
        _compcolor = '#d9d9d9' # X11 color: 'gray85'
        _ana1color = '#d9d9d9' # X11 color: 'gray85'
        _ana2color = '#ececec' # Closest X11 color: 'gray92'

        top.geometry("1000x694+366+210")
        top.minsize(148, 1)
        top.maxsize(1924, 1055)
        top.resizable(1,  1)
        top.title("New Toplevel")
        top.configure(background="#dfffff")

        self.menubar = tk.Menu(top,font="TkMenuFont",bg=_bgcolor,fg=_fgcolor)
        top.configure(menu = self.menubar)

        
        

        self.b3 = tk.Button(top)
        self.b3.place(relx=0.48, rely=0.173, height=33, width=216)
        self.b3.configure(activebackground="#ececec")
        self.b3.configure(activeforeground="#000000")
        self.b3.configure(background="#c1ffc1")
        self.b3.configure(disabledforeground="#a3a3a3")
        self.b3.configure(foreground="#000000")
        self.b3.configure(highlightbackground="#d9d9d9")
        self.b3.configure(highlightcolor="black")
        self.b3.configure(pady="0")
        self.b3.configure(text='''Our Services''')
        self.b3.configure(command=lambda:[top.destroy(),open_health_test()])

        self.b4 = tk.Button(top)
        self.b4.place(relx=0.48, rely=0.231, height=33, width=216)
        self.b4.configure(activebackground="#ececec")
        self.b4.configure(activeforeground="#000000")
        self.b4.configure(background="#c1ffc1")
        self.b4.configure(disabledforeground="#a3a3a3")
        self.b4.configure(foreground="#000000")
        self.b4.configure(highlightbackground="#d9d9d9")
        self.b4.configure(highlightcolor="black")
        self.b4.configure(pady="0")
        self.b4.configure(text='''Contact Us''')
        self.b4.configure(command = contact_us)
        

        self.b5 = tk.Button(top)
        self.b5.place(relx=0.48, rely=0.288, height=33, width=216)
        self.b5.configure(activebackground="#ececec")
        self.b5.configure(activeforeground="#000000")
        self.b5.configure(background="#c1ffc1")
        self.b5.configure(disabledforeground="#a3a3a3")
        self.b5.configure(foreground="#000000")
        self.b5.configure(highlightbackground="#d9d9d9")
        self.b5.configure(highlightcolor="black")
        self.b5.configure(pady="0")
        self.b5.configure(text='''Help!''')
        self.b5.configure(command = Help)


        self.message1 = tk.Message(top)
        self.message1.place(relx=0.03, rely=0.043, relheight=0.187
                , relwidth=0.396)
        self.message1.configure(background="#ffffb0")
        self.message1.configure(foreground="#000000")
        self.message1.configure(highlightbackground="#d9d9d9")
        self.message1.configure(highlightcolor="black")
        self.message1.configure(text='''Hello Friend!
Welcome To Our
Application

stay fit! stay healthy!''')
        self.message1.configure(width=396)

        self.text1 = tk.Text(top)
        self.text1.place(relx=0.47, rely=0.865, relheight=0.078, relwidth=0.514)
        self.text1.configure(background="white")
        self.text1.configure(font="TkTextFont")
        self.text1.configure(foreground="black")
        self.text1.configure(highlightbackground="#d9d9d9")
        self.text1.configure(highlightcolor="black")
        self.text1.configure(insertbackground="black")
        self.text1.configure(selectbackground="blue")
        self.text1.configure(selectforeground="white")
        self.text1.configure(wrap="word")

        self.l3 = tk.Label(top)
        self.l3.place(relx=0.47, rely=0.749, height=66, width=512)
        self.l3.configure(background="#d9d9d9")
        self.l3.configure(disabledforeground="#a3a3a3")
        self.l3.configure(foreground="#000000")
        self.l3.configure(highlightbackground="#f0f0f0f0f0f0")
        self.l3.configure(relief="groove")
        self.l3.configure(text='''Thank You for considering us. we are considerate to have your reviews''')

        self.l2 = tk.Label(top)
        self.l2.place(relx=0.05, rely=0.36, height=416, width=342)
        self.l2.configure(background="#ffffdf")
        self.l2.configure(disabledforeground="#a3a3a3")
        self.l2.configure(foreground="#000000")
        
        
        if time.strftime("%w")=='5':
            self.l2.configure(text='''TIP OF THE DAY

Meat can be a nutritious and healthy part of your
diet. It’s very high in protein and contains 
various important nutrients.

However, problems occur when meat is overcooked
or burnt. This can lead to the formation of 
harmful compounds that raise your risk of
cancer (38Trusted Source).

When you cook meat, make sure not
to overcook or burn it.''')
        
        if time.strftime("%w")=='0':
            self.l2.configure(text='''TIP OF THE DAY
            
Vegetables and fruits are loaded with prebiotic 
fiber, vitamins, minerals, and many antioxidants,
some of which have potent biological effects.

Studies show that people who eat the most vegetables
and fruits live longer and have a lower risk of heart
disease, type 2 diabetes, obesity, and other 
illnesses (50, 51).''')
        
        elif time.strftime("%w")=='1':
            self.l2.configure(text='''TIP OF THE DAY
            
Eating enough protein is vital for optimal health.

What’s more, this nutrient is particularly important
for weight loss (52Trusted Source).

High protein intake can boost metabolism significantly
while making you feel full enough to automatically
eat fewer calories. It can also reduce cravings and
your desire to snack late at night (53Trusted Source,
54Trusted Source, 55Trusted Source, 56Trusted Source).

Sufficient protein intake has also been shown to 
lower blood sugar and blood pressure levels''')
        
        elif time.strftime("%w")=='2':
            self.l2.configure(text='''TIP OF THE DAY

Drinking enough water can have numerous benefits.

Surprisingly, it can boost the number of calories you burn.

Two studies note that it can increase metabolism by
24–30% over 1–1.5 hours. This can amount to 96 additional
calories burned if you drink 8.4 cups (2 liters) of 
water per day (35Trusted Source, 36Trusted Source).

The optimal time to drink it is before meals. One
study showed that downing 2.1 cups (500 ml) of water
30 minutes before each meal increased weight loss 
by 44% (37Trusted Source)''')
        
        elif time.strftime("%w")=='3':
            self.l2.configure(text='''TIP OF THE DAY
            
The importance of getting enough quality sleep 
cannot be overstated.

Poor sleep can drive insulin resistance, disrupt
your appetite hormones, and reduce your physical
and mental performance (26Trusted Source, 27Trusted Source,
28TrustedSource, 29Trusted Source).

What’s more, poor sleep is one of the strongest individual
risk factors for weight gain and obesity. One study linked 
insufficient sleep to an 89% and 55% increased risk of obesity 
in children and adults, respectively (30Trusted Source).''')
        
        elif time.strftime("%w")=='4':
            self.l2.configure(text='''TIP OF THE DAY
            
Processed junk food is incredibly unhealthy.

These foods have been engineered to trigger your 
pleasure centers, so they trick your brain into 
overeating — even promoting food addiction in some
people (15Trusted Source).

They’re usually low in fiber, protein, and micronutrients 
but high in unhealthy ingredients like added sugar and 
refined grains. Thus, they provide mostly empty calories.''')
        
        elif time.strftime("%w")=='6':
            self.l2.configure(text='''TIP OF THE DAY
    
Despite being high in fat, nuts are incredibly nutritious 
and healthy.

They’re loaded with magnesium, vitamin E, fiber, 
and various other nutrients (9Trusted Source).

Studies demonstrate that nuts can help you lose 
weight and may help fight type 2 diabetes and heart
disease (10Trusted Source, 11Trusted Source, 12Trusted Source).

Additionally, your body doesn’t absorb 10–15% of the
calories in nuts. Some evidence also suggests that this
food can boost metabolism (13Trusted Source).

In one study, almonds were shown to increase weight
loss by 62%, compared with complex carbs''')
    
        global option1
        option1 = StringVar()
        
        self.Radiobutton1 = tk.Radiobutton(top)
        self.Radiobutton1.place(relx=0.85, rely=0.677, relheight=0.045
                , relwidth=0.108)
        self.Radiobutton1.configure(activebackground="#ececec")
        self.Radiobutton1.configure(activeforeground="#000000")
        self.Radiobutton1.configure(background="#fb1a41")
        self.Radiobutton1.configure(disabledforeground="#a3a3a3")
        self.Radiobutton1.configure(foreground="#000000")
        self.Radiobutton1.configure(highlightbackground="#d9d9d9")
        self.Radiobutton1.configure(highlightcolor="black")
        self.Radiobutton1.configure(justify='left')
        self.Radiobutton1.configure(value='''BAD''')
        self.Radiobutton1.configure(text='''BAD''')
        self.Radiobutton1.configure(var=option1)

        self.Radiobutton2 = tk.Radiobutton(top)
        self.Radiobutton2.place(relx=0.85, rely=0.62, relheight=0.046
                , relwidth=0.108)
        self.Radiobutton2.configure(activebackground="#ececec")
        self.Radiobutton2.configure(activeforeground="#000000")
        self.Radiobutton2.configure(background="#ff7e40")
        self.Radiobutton2.configure(disabledforeground="#a3a3a3")
        self.Radiobutton2.configure(foreground="#000000")
        self.Radiobutton2.configure(highlightbackground="#d9d9d9")
        self.Radiobutton2.configure(highlightcolor="black")
        self.Radiobutton2.configure(justify='left')
        self.Radiobutton2.configure(value='''AVERAGE''')
        self.Radiobutton2.configure(text='''AVERAGE''')
        self.Radiobutton2.configure(var=option1)

        self.Radiobutton3 = tk.Radiobutton(top)
        self.Radiobutton3.place(relx=0.85, rely=0.562, relheight=0.045
                , relwidth=0.108)
        self.Radiobutton3.configure(activebackground="#ececec")
        self.Radiobutton3.configure(activeforeground="#000000")
        self.Radiobutton3.configure(background="#44ff44")
        self.Radiobutton3.configure(disabledforeground="#a3a3a3")
        self.Radiobutton3.configure(foreground="#000000")
        self.Radiobutton3.configure(highlightbackground="#d9d9d9")
        self.Radiobutton3.configure(highlightcolor="black")
        self.Radiobutton3.configure(justify='left')
        self.Radiobutton3.configure(value='''GOOD''')
        self.Radiobutton3.configure(text='''GOOD''')
        self.Radiobutton3.configure(var=option1)

        self.Label1 = tk.Label(top)
        self.Label1.place(relx=0.7, rely=0.562, height=106, width=122)
        self.Label1.configure(background="#b8b8b8")
        self.Label1.configure(disabledforeground="#a3a3a3")
        self.Label1.configure(foreground="#000000")
        self.Label1.configure(text='''RATE

US''')

class login():

        def __init__(self, master):
            self.master=master
            self.master.geometry("500x500+500+180")
            self.master.resizable(0,0)
            self.master.title("Welcome")
            global mbg
            mbg = PhotoImage(file = 'Image/background.png')
            self.bg = Canvas(root,width=1600,height=820)
            self.bg.create_image(0,0,anchor = NW,image = mbg)
            self.bg.grid(row=0,rowspan=50,column=0,columnspan=50)
            global login_img
            login_img = PhotoImage(file = 'Image/login.png')
            global reg
            reg = PhotoImage(file = 'Image/register.gif')
            self.l1 = Label(text="WELCOME!!Select Your Choice", bg="pink", font=("Georgia", 13),fg="gray") 
            self.l1.place(relx=0.5, rely = 0.2, anchor = CENTER)
            self.b1 = Button(root,bg = 'black',image = login_img, command = self.login,relief=RAISED)
            self.b1.place(relx=0.5, rely = 0.4, anchor = CENTER)
            self.b2 = Button(text="Register",bg = 'black',image = reg,command=self.register,relief=RAISED)
            self.b2.place(relx=0.5, rely = 0.6, anchor = CENTER)
        def register(self):
            root.geometry("500x420")
            root.maxsize(500,420)
            global username
            global password
            global cityname
            global username_entry
            global password_entry
            global cityname_entry
            username = StringVar()
            password = StringVar()
            cityname = StringVar()
            global rbg
            rbg = PhotoImage(file = 'Image/regbg.gif')
            global regbg
            regbg = Canvas(root,width=1600,height=820)
            regbg.create_image(0,0,anchor = NW,image = rbg)
            regbg.grid(row=0,rowspan=50,column=0,columnspan=50)

            l1=Label(root, text="Please enter details below", bg='LightSteelBlue3', font = "Helvetica 12 bold italic")
            l1.place(relx=0.5, rely = 0.1, anchor = CENTER)
    
            username_lable = Label(root, text="Username : ",bg='LightSteelBlue3', font = "Helvetica 12 bold italic")
            username_lable.place(relx=0.2, rely = 0.2, anchor = CENTER)
            username_entry = Entry(root, textvariable=username, width = 35, bg = "light blue", fg = "red", borderwidth = 10)
            username_entry.place(relx=0.6, rely = 0.2, anchor = CENTER)
            password_lable = Label(root, text="Password : ",bg='LightSteelBlue3', font = "Helvetica 12 bold italic")
            password_lable.place(relx=0.2, rely = 0.3, anchor = CENTER)
            password_entry = Entry(root, textvariable=password, show='*', width = 35, bg = "light blue", fg = "red", borderwidth = 10)
            password_entry.place(relx=0.6, rely = 0.3, anchor = CENTER)
            cityname_lable = Label(root, text="Cityname : ",bg='LightSteelBlue3', font = "Helvetica 12 bold italic")
            cityname_lable.place(relx=0.2, rely = 0.4, anchor = CENTER)
            cityname_entry = Entry(root, textvariable=cityname, width = 35, bg = "light blue", fg = "red", borderwidth = 10)
            cityname_entry.place(relx=0.6, rely = 0.4, anchor = CENTER)
            global reg
            reg = PhotoImage(file = 'Image/register.gif')
            b1 = Button(root,bg='black', image = reg, command = self.register_verify,relief=RAISED)
            b1.place(relx=0.4, rely = 0.6, anchor = CENTER)

        def login(self):
            root.geometry("500x420")
            root.maxsize(500,420)
            global lbg
            lbg = PhotoImage(file = 'Image/regbg.gif')
            global logbg
            logbg = Canvas(root,width=1600,height=820)
            logbg.create_image(0,0,anchor = NW,image = lbg)
            logbg.grid(row=0,rowspan=50,column=0,columnspan=50)
            l1=Label(root, text="Please enter details below to login", bg='LightSteelBlue3', font = "Helvetica 12 bold italic")
            l1.place(relx=0.5, rely = 0.1, anchor = CENTER)

            
        
            global username_verify
            global password_verify

            username_verify = StringVar()
            password_verify = StringVar()
    
            global username_login_entry
            global password_login_entry
            global login_img
            login_img = PhotoImage(file = 'Image/login.png')

            l2 = Label(root, text="Username : ",bg='LightSteelBlue3', font = "Helvetica 12 bold italic")
            l2.place(relx=0.2, rely = 0.2, anchor = CENTER)
            username_login_entry = Entry(root, textvariable=username_verify, width = 35, bg = "light blue", fg = "red", borderwidth = 10)
            username_login_entry.place(relx=0.6, rely = 0.2, anchor = CENTER)
            l3 = Label(root, text="Password : ",bg='LightSteelBlue3', font = "Helvetica 12 bold italic")
            l3.place(relx=0.2, rely = 0.3, anchor = CENTER)
            password_login_entry = Entry(root, textvariable=password_verify, show= '*', width = 35, bg = "light blue", fg = "red", borderwidth = 10)
            password_login_entry.place(relx=0.6, rely = 0.3, anchor = CENTER)
            b1 = Button(root,bg='black', image = login_img, command = self.login_verify,relief=RAISED)
            b1.place(relx=0.4, rely = 0.5, anchor = CENTER)

        def register_verify(self):
            global username_info
            global password_info
            global cityname_info
            global city_name_entry
            username_info = username.get()
            password_info = password.get()
            cityname_info=  cityname.get()
            list_of_files = os.listdir()
            if username_info in list_of_files:
                file1 = open(username_info ,"r")
                verify = file1.read().splitlines()
                self.register_failure()

            else:
                self.register_success()
            username_entry.delete(0, END)
            password_entry.delete(0, END)
            cityname_entry.delete(0, END)
        def register_success(self):
            file = open(username_info, "w")
            file.write(username_info + "\n")
            file.write(password_info + "\n")
            file.write(cityname_info)
            file.close()
            Label(root, text="Registration Success", fg="green", font=("calibri", 13)).place(relx=0.5,rely=0.7,anchor=CENTER)
        def register_failure(self):
            global register_failure_screen
            register_failure_screen = Toplevel(root)
            register_failure_screen.title("failure")
            register_failure_screen.geometry("150x100")
            Label(register_failure_screen, text="user already exists").pack()
            Button(register_failure_screen, text="OK", command=self.register_exists,relief=RAISED).pack()
            
        def register_exists(self):
            register_failure_screen.destroy()
                       
       
        def login_verify(self):
            username1 = username_verify.get()
            password1 = password_verify.get()
        

            list_of_files = os.listdir()
            if username1 in list_of_files:
                file1 = open(username1, "r")
                verify = file1.read().splitlines()
                if password1 in verify:
                    self.login_sucess()

                else:
                    self.password_not_recognised()

            else:
                self.user_not_found()


        def login_sucess(self):
            global login_success_screen
            login_success_screen = Toplevel(root)
            login_success_screen.title("Success")
            login_success_screen.geometry("150x100")
            Label(login_success_screen, text="Login Success").pack()
            Button(login_success_screen, text="OK", command=self.gotohealth_test,relief=RAISED).pack()

        def password_not_recognised(self):
            global password_not_recog_screen
            password_not_recog_screen = Toplevel(root)
            password_not_recog_screen.title("Success")
            password_not_recog_screen.geometry("150x100")
            Label(password_not_recog_screen, text="Invalid Password ").pack()
            Button(password_not_recog_screen, text="OK", command=self.delete_password_not_recognised,relief=RAISED).pack()


        def user_not_found(self):
            global user_not_found_screen
            user_not_found_screen = Toplevel(root)
            user_not_found_screen.title("Success")
            user_not_found_screen.geometry("150x100")
            Label(user_not_found_screen, text="User Not Found").pack()
            Button(user_not_found_screen, text="OK", command=self.delete_user_not_found_screen,relief=SUNKEN).pack()
 
        def delete_password_not_recognised(self):
            password_not_recog_screen.destroy()


        def delete_user_not_found_screen(self):
            user_not_found_screen.destroy()
        
        
        def gotohealth_test1(self):
            
            root.withdraw()
            vp_start_gui()
        
        def gotohealth_test(self):
            login_success_screen.destroy()
            root.withdraw()
            vp_start_gui()
#             root.destroy()
#             health_testgui=health_test(root)

        
        
    


global bmi
bmi = PhotoImage(file="Image\\bmi_calculator.png")

global cal
cal=PhotoImage(file="Image/calculate.png")
global bg
bg = PhotoImage(file="Image/bmibg.png")
global scale
scale = PhotoImage(file = "Image/scale.png")
global cabg
cabg = PhotoImage(file="Image\\cabg.png")
global ans
global bg
bg1 = PhotoImage(file = 'Image/cscbg.png')
global bg
bg2 = PhotoImage(file = 'Image/ibw.png')
global cali
cali=PhotoImage(file = 'Image/calorie_calc.png')
global idl
idl=PhotoImage(file = 'Image/ideal_weight.png')
global corona
corona=PhotoImage(file = 'Image/corona.png')





class health_test:

    def __init__(self,master):
        
        self.master=master
        self.master.geometry("600x400")
#         self.master.resizable(0,0)
        self.master.maxsize(800,450)
        self.master.minsize(800,450)
        self.master.title("Health Test")
        global mbg
        mbg = PhotoImage(file = 'Image/background.png')
        self.bg = Canvas(self.master,width=1600,height=820)
        self.bg.create_image(0,0,anchor = NW,image = mbg)
        self.bg.grid(row=0,rowspan=50,column=0,columnspan=50)
        label_1=Label(self.master, text='Welcome To The Health Test Program')
        label_1.grid(row=0,column=0)
        
        
        self.l1 = tk.Label(self.master)
        self.l1.place(relx=0.4, rely=0.101, height=36, width=212)
        self.l1.configure(background="#00ffff")
        self.l1.configure(disabledforeground="#a3a3a3")
        self.l1.configure(foreground="#000000")
        self.l1.configure(text='''Our Services''')
        
         
#         self.bmi_button = Button(self.master,image = bmi,bd='0',height='24',width='100',command=self.Calculate_BMI)

        self.b3 = tk.Button(root)
        self.b3.place(relx=0.40, rely=0.187, height=33, width=216)
        self.b3.configure(activebackground="#ececec")
        self.b3.configure(activeforeground="#000000")
        self.b3.configure(background="#c1ffc1")
        self.b3.configure(disabledforeground="#a3a3a3")
        self.b3.configure(foreground="#000000")
        self.b3.configure(highlightbackground="#d9d9d9")
        self.b3.configure(highlightcolor="black")
        self.b3.configure(pady="0")
        self.b3.configure(text='''BMI CALCULATOR''')
        self.b3.configure(command=self.Calculate_BMI)
        
        
        self.b4 = tk.Button(root)
        self.b4.place(relx=0.40, rely=0.274, height=33, width=216)
        self.b4.configure(activebackground="#ececec")
        self.b4.configure(activeforeground="#000000")
        self.b4.configure(background="#c1ffc1")
        self.b4.configure(disabledforeground="#a3a3a3")
        self.b4.configure(foreground="#000000")
        self.b4.configure(highlightbackground="#d9d9d9")
        self.b4.configure(highlightcolor="black")
        self.b4.configure(pady="0")
        self.b4.configure(text='''CALORIE CALCULATOR''')
        self.b4.configure(command=self.cal_calculator)
        
        self.b5 = tk.Button(root)
        self.b5.place(relx=0.40, rely=0.360, height=33, width=216)
        self.b5.configure(activebackground="#ececec")
        self.b5.configure(activeforeground="#000000")
        self.b5.configure(background="#c1ffc1")
        self.b5.configure(disabledforeground="#a3a3a3")
        self.b5.configure(foreground="#000000")
        self.b5.configure(highlightbackground="#d9d9d9")
        self.b5.configure(highlightcolor="black")
        self.b5.configure(pady="0")
        self.b5.configure(text='''IDEAL WEIGHT CALCULATOR''')
        self.b5.configure(command=self.ideal_weight_calculator)

        self.b6 = tk.Button(root)
        self.b6.place(relx=0.40, rely=0.447, height=33, width=216)
        self.b6.configure(activebackground="#ececec")
        self.b6.configure(activeforeground="#000000")
        self.b6.configure(background="#c1ffc1")
        self.b6.configure(disabledforeground="#a3a3a3")
        self.b6.configure(foreground="#000000")
        self.b6.configure(highlightbackground="#d9d9d9")
        self.b6.configure(highlightcolor="black")
        self.b6.configure(pady="0")
        self.b6.configure(text='''Covid-19 SELF TESTER''')
        self.b6.configure(command=self.corona_symptoms_checker)
        

        
    
    def calc(self):
        global a
        global b
        h1=StringVar()
        w1=StringVar()
        e=StringVar()
        s1= self.h1.get()
        l= Label(bmiscreen, text='Your Body Mass Index is: ',fg = "light green", bg = "dark green", font = "Helvetica 12 bold italic")
        s2= self.w1.get()
        b=float(s2)
        a=float(s1)
        e=Entry(bmiscreen, width = 35, bg = "light blue", fg = "red", borderwidth = 10)
        e.insert(0,b/(a*a))
        l.place(relx = 0.2, rely = 0.7, anchor = CENTER)
        e.place(relx = 0.6, rely = 0.7, anchor = CENTER)
        if float(e.get())>0.0:
            l1= Label(bmiscreen, image = scale).place(relx = 0.5, rely = 0.9, anchor = CENTER)
        #mcrs.execute("create table bmi123(height varchar(255),weight varchar(255),bmi varchar(255))")
        mcrs.execute("insert into bmi123 values(%s,%s,%s)",(a,b,e.get()))
        con.commit()
        mcrs.execute("select * from bmi123")
        result=mcrs.fetchall()
        for i in result:
            print(i)
        
    def Calculate_BMI(self):
        
        
        global bmiscreen
        bmiscreen = Toplevel(root)
        bmiscreen.title("BMI CALCULATOR") 
        bmiscreen.geometry("400x400")
        bmiscreen.maxsize(650,450)
        bmiscreen.minsize(650,450)
        bmibg = Canvas(bmiscreen,width=1600,height=820)
        bmibg.create_image(0,0,anchor = NW,image = bg)
        bmibg.grid(row=0,rowspan=50,column=0,columnspan=50)
        
        
        
        self.h1 = Entry(bmiscreen,width = 35, bg = "light blue", fg = "red", borderwidth = 10) 
        self.w1 = Entry(bmiscreen, width = 35, bg = "light blue", fg = "red", borderwidth = 10)
        self.h1.insert(0,'Enter height in meters')
        self.w1.insert(0,'Enter weight in kg')
        Label(bmiscreen, text='Height', bg='LightSteelBlue3', font = "Helvetica 12 bold italic").place(relx = 0.2, rely = 0.1, anchor = CENTER)
        Label(bmiscreen, text='Weight', bg='LightSteelBlue3', font = "Helvetica 12 bold italic").place(relx = 0.2, rely = 0.3, anchor = CENTER)
        self.h1.place(relx = 0.5, rely = 0.1, anchor = CENTER)
        self.w1.place(relx = 0.5, rely = 0.3, anchor = CENTER)
        self.button1 = Button(bmiscreen,image = cal,bd='0',height='38',width='138',command = self.calc)
        self.button1.place(relx = 0.5, rely = 0.5, anchor = CENTER)

    def calculate_calorie(self):
        global h
        global w
        global a
        global v
        h=StringVar()
        w=StringVar()
        a=StringVar()
        v=StringVar()
        s1=height.get()
        s2=weight.get()
        s3=age.get()
        h=float(s1)
        w = float(s2)
        a = float(s3)
        
        o = option.get()
        if o == 'male':
            ans = (13.397*w) + (4.799*h*100) - (5.677*a) + 88.362
        else:
            ans = (9.247*w) + (3.098*h*100) - 4.330*a + 447.593
            
        v = variable.get()
        if v == 'Sedentary: little or no exercise':
            ans = ans*1.2
        elif v == 'Moderately active: moderate exercise':
            ans = ans*1.55
        elif v == 'Very active: intense exercise every day':
            ans = ans*1.725
        elif v == 'Lightly active: light exercise/ sports 1-3 days/week':
            ans = ans*1.375
        elif v == 'Extra active: intense exercise 2 or more times per day':
            ans = ans*1.9
        
        e=Entry(calscreen, width = 35, bg = "light blue", fg = "red", borderwidth = 10)
        e.insert(0,ans)
        e.place(relx = 0.6, rely = 0.7, anchor = CENTER)
        
        l= Label(calscreen, text='To Maintain weight:',fg = "light green", bg = "dark green", font = "Helvetica 12 bold italic")
        l.place(relx = 0.2, rely = 0.7, anchor = CENTER)
        
        l1= Label(calscreen, text='Mild weight loss(0.25 kg/week):',fg = "light green", bg = "dark green", font = "Helvetica 12 bold italic")
        l1.place(relx = 0.2, rely = 0.8, anchor = CENTER)
        
        l1= Label(calscreen, text='Weight loss(0.5 kg/week):',fg = "light green", bg = "dark green", font = "Helvetica 12 bold italic")
        l1.place(relx = 0.2, rely = 0.9, anchor = CENTER)
        
        e1=Entry(calscreen, width = 35, bg = "light blue", fg = "red", borderwidth = 10)
        e1.insert(0,ans-250)
        e1.place(relx = 0.6, rely = 0.8, anchor = CENTER)
        
        e2=Entry(calscreen, width = 35, bg = "light blue", fg = "red", borderwidth = 10)
        e2.insert(0,ans-500)
        e2.place(relx = 0.6, rely = 0.9, anchor = CENTER)
      
      #  mcrs.execute("create table calor(height varchar(255),weight varchar(255),age varchar(255),work varchar(255),maintain varchar(255),mild  varchar(255),wloss varchar(255))")
        mcrs.execute("insert into calor values(%s,%s,%s,%s,%s,%s,%s)",(h,w,a,v,e.get(),e1.get(),e2.get()))
        con.commit()
        mcrs.execute("select * from calor")
        result=mcrs.fetchall()
        for i in result:
            print(i) 
        
        
    def cal_calculator(self):
        global calscreen
        calscreen = Toplevel(root)
        calscreen.title("CALORIE CALCULATOR")
        calscreen.geometry("400x400")
        calscreen.maxsize(650,450)
        calscreen.minsize(650,450)
        
        
        calbg = Canvas(calscreen,width=1600,height=820)
        calbg.create_image(0,0,anchor = NW,image = cabg)
        calbg.grid(row=0,rowspan=50,column=0,columnspan=50)
        
        global option
        option = StringVar()
        R1 = Radiobutton(calscreen, text="MALE", bg = "light blue", font = "Helvetica 12 bold italic", value="male", var=option)
        R2 = Radiobutton(calscreen, text="FEMALE", bg = "light blue", font = "Helvetica 12 bold italic", value="female", var=option)
        R1.place(relx=0.4, rely = 0.1, anchor = CENTER)
        R2.place(relx=0.55, rely = 0.1, anchor = CENTER)
        
        height_label=Label(calscreen, text='Height', bg='LightSteelBlue3', font = "Helvetica 12 bold italic")
        height_label.place(relx = 0.1, rely = 0.2, anchor = CENTER)
        
        weight_label=Label(calscreen, text='Weight', bg='LightSteelBlue3', font = "Helvetica 12 bold italic")
        weight_label.place(relx = 0.1, rely = 0.3, anchor = CENTER)
        
        gender_label=Label(calscreen, text='Gender', bg='LightSteelBlue3', font = "Helvetica 12 bold italic")
        gender_label.place(relx = 0.1, rely = 0.1, anchor = CENTER)
        
        age_label=Label(calscreen, text='Age', bg='LightSteelBlue3', font = "Helvetica 12 bold italic")
        age_label.place(relx = 0.1, rely = 0.4, anchor = CENTER)
        
        activity_label=Label(calscreen, text='Activity', bg='LightSteelBlue3', font = "Helvetica 12 bold italic")
        activity_label.place(relx = 0.1, rely = 0.5, anchor = CENTER)
        
        global height
        global weight
        global age
        height = Entry(calscreen,width = 35, bg = "light blue", fg = "red", borderwidth = 10) 
        height.place(relx = 0.5, rely = 0.2, anchor = CENTER)
        
        weight = Entry(calscreen, width = 35, bg = "light blue", fg = "red", borderwidth = 10)
        weight.place(relx = 0.5, rely = 0.3, anchor = CENTER)
        
        
        age = Entry(calscreen, width = 35, bg = "light blue", fg = "red", borderwidth = 10)
        age.place(relx = 0.5, rely = 0.4, anchor = CENTER)
        
        
        height.insert(0,'Enter height in meters')
        weight.insert(0,'Enter weight in kg')
        age.insert(0,'Enter your age')
        
        
        
        OPTIONS = ["Sedentary: little or no exercise","Lightly active: light exercise/ sports 1-3 days/week",
                   "Moderately active: moderate exercise",
                   "Very active: intense exercise every day",
                   "Extra active: intense exercise 2 or more times per day"
                  ]
        global variable
        variable = StringVar()
        variable.set(OPTIONS[0]) # default value
        w = OptionMenu(calscreen, variable,"Sedentary: little or no exercise", "Lightly active: light exercise/ sports 1-3 days/week","Moderately active: moderate exercise","Very active: intense exercise every day","Extra active: intense exercise 2 or more times per day" )
        w.config(width=45, bg = "light blue", fg = "red", borderwidth = 5)
        w.place(relx=0.5,rely=0.5,anchor=CENTER)
        
        
        
        button1 = Button(calscreen,image = cal,bd='0',height='38',width='138',command = self.calculate_calorie)
        button1.place(relx = 0.5, rely = 0.6, anchor = CENTER)
        
    def idweight_calculator(self):
        global h
        global a
        
        s1=height.get()
        s2=age.get()
        h=float(s1)
        a = float(s2)
        
        o = option.get()
        if o == 'male':
            ans = 50 + (0.91*((h*100) - 152.4))
        else:
            ans = 45.5 + (0.91*((h*100) - 152.4))
            
        e=Entry(idweight_screen, width = 35, bg = "light blue", fg = "red", borderwidth = 10)
        e.insert(0,ans)
        e.place(relx = 0.6, rely = 0.7, anchor = CENTER)
        
        l= Label(idweight_screen, text='Ideal wieght is:',fg = "light green", bg = "dark green", font = "Helvetica 12 bold italic")
        l.place(relx = 0.2, rely = 0.7, anchor = CENTER)
        
    #    mcrs.execute("create table ideal(height varchar(255),age varchar(255),ideal varchar(255))")
        mcrs.execute("insert into ideal values(%s,%s,%s)",(h,a,e.get()))
        con.commit()
        mcrs.execute("select * from ideal")
        result=mcrs.fetchall()
        for i in result:
            print(i) 
        
    def ideal_weight_calculator(self):
        
        global idweight_screen
        idweight_screen = Toplevel(root)
        idweight_screen.title("IDEAL WEIGHT CALCULATOR")
        idweight_screen.geometry("400x400")
        idweight_screen.maxsize(650,435)
        idweight_screen.minsize(650,435)
        
        
        ibwbg = Canvas(idweight_screen,width=1600,height=820)
        ibwbg.create_image(0,0,anchor = NW,image = bg2)
        ibwbg.grid(row=0,rowspan=50,column=0,columnspan=50)
        
        
        global option
        option = StringVar()
        R1 = Radiobutton(idweight_screen, text="MALE", bg = "light blue", font = "Helvetica 12 bold italic", value="male", var=option)
        R2 = Radiobutton(idweight_screen, text="FEMALE", bg = "light blue", font = "Helvetica 12 bold italic", value="female", var=option)
        R1.place(relx=0.4, rely = 0.1, anchor = CENTER)
        R2.place(relx=0.55, rely = 0.1, anchor = CENTER)
        
        gender_label=Label(idweight_screen, text='Gender', bg='LightSteelBlue3', font = "Helvetica 12 bold italic")
        gender_label.place(relx = 0.1, rely = 0.1, anchor = CENTER)
        
        age_label=Label(idweight_screen, text='Age', bg='LightSteelBlue3', font = "Helvetica 12 bold italic")
        age_label.place(relx = 0.1, rely = 0.4, anchor = CENTER)
        
        height_label=Label(idweight_screen, text='Height', bg='LightSteelBlue3', font = "Helvetica 12 bold italic")
        height_label.place(relx = 0.1, rely = 0.25, anchor = CENTER)
        
        global age
        age = Entry(idweight_screen, width = 35, bg = "light blue", fg = "red", borderwidth = 10)
        age.place(relx = 0.5, rely = 0.4, anchor = CENTER)
        
        global height
        height = Entry(idweight_screen,width = 35, bg = "light blue", fg = "red", borderwidth = 10) 
        height.place(relx = 0.5, rely = 0.25, anchor = CENTER)
        
        height.insert(0,'Enter height in meters')
        age.insert(0,'Enter your age')
        
#         global cal
#         cal=PhotoImage(file="Image/calculate.png")
        
        button1 = Button(idweight_screen,image = cal,bd='0',height='38',width='138',command = self.idweight_calculator)
        button1.place(relx = 0.45, rely = 0.55, anchor = CENTER)
        
    
    def check_csc(self):
        
        global l3
        l3=0
        l1=Label(csc_screen, text="You need to see a Doctor!", bg='LightSteelBlue3', font = "Helvetica 12 bold italic",width=35)
        global l4
        l4=0
        if l3 == 1:
            l1.destroy()
        if l4 ==1:
            l2.destroy
        l2=Label(csc_screen, text="You only need to follow social distancing!", bg='LightSteelBlue3', font = "Helvetica 12 bold italic",width=35)
        global o
        o=option1.get()
        a = 0
        if o == '1':
            a=a+1
        if option2.get() == '1':
            a=a+1
        if option3.get() == '1':
            a=a+1
        if option4.get() == '1':
            a=a+1
        if option5.get() == '1':
            a=a+1
        if option6.get() == '1':
            a=a+1
        if option7.get() == '1':
            a=a+1
        if option8.get() == '1':
            a=a+1
        if option9.get() == '1':
            a=a+1
        if option10.get() == '1':
            a=a+1
        
        
        
        
        
        if a>=5:
            l1.place(relx=0.5, rely = 0.85, anchor = CENTER)
            l3=1
        else:
            l2.place(relx=0.5, rely = 0.85, anchor = CENTER)
            l4=1
         
        
            
    
    def corona_symptoms_checker(self):
        
        global csc_screen
        csc_screen = Toplevel(root)
        csc_screen.title("CORONAVIRUS SELF CHECKER")
        csc_screen.geometry("400x400")
        csc_screen.maxsize(650,420)
        csc_screen.minsize(650,420)
        
        
        ibwbg = Canvas(csc_screen,width=1600,height=820)
        ibwbg.create_image(0,0,anchor = NW,image = bg1)
        ibwbg.grid(row=0,rowspan=50,column=0,columnspan=50)
        
        
        global option1,option2,option3,option4,option5,option6,option7,option8,option9,option10
        option1 = StringVar()
        option2 = StringVar()
        option3 = StringVar()
        option4 = StringVar()
        option5 = StringVar()
        option6 = StringVar()
        option7 = StringVar()
        option8 = StringVar()
        option9 = StringVar()
        option10 = StringVar()
        
        option1.set(0)
        option2.set(0)
        option3.set(0)
        option4.set(0)
        option5.set(0)
        option6.set(0)
        option7.set(0)
        option8.set(0)
        option9.set(0)
        option10.set(0)
        l1=Label(csc_screen, text="Select from the following:", bg='LightSteelBlue3', font = "Helvetica 12 bold italic")
        l1.place(relx=0.5, rely = 0.1, anchor = CENTER)
        
        R1 = Checkbutton(csc_screen, text="Fever", bg = "light blue", font = "Helvetica 10 bold italic", var=option1)
        R2 = Checkbutton(csc_screen, text="Cough", bg = "light blue", font = "Helvetica 10 bold italic", var=option2)
        R3 = Checkbutton(csc_screen, text="Shortness of breath", bg = "light blue", font = "Helvetica 10 bold italic",  var=option3)
        R4 = Checkbutton(csc_screen, text="Sore Throat", bg = "light blue", font = "Helvetica 10 bold italic",  var=option4)
        R5 = Checkbutton(csc_screen, text="Headache", bg = "light blue", font = "Helvetica 10 bold italic",  var=option5)
        R6 = Checkbutton(csc_screen, text="Diarrhea", bg = "light blue", font = "Helvetica 10 bold italic",  var=option6)
        R7 = Checkbutton(csc_screen, text="Nausea or vomiting", bg = "light blue", font = "Helvetica 10 bold italic",  var=option7)
        R8 = Checkbutton(csc_screen, text="Loss of smell or taste", bg = "light blue", font = "Helvetica 10 bold italic",  var=option8)
        R9 = Checkbutton(csc_screen, text="Body aches", bg = "light blue", font = "Helvetica 10 bold italic",  var=option9)
        R10 = Checkbutton(csc_screen, text="Came contact(within 6 feet) with a covid patient ", bg = "light blue", font = "Helvetica 10 bold italic",  var=option10)
        
        
        R1.place(relx=0.2,rely=0.2,anchor=CENTER)
        R2.place(relx=0.2,rely=0.3,anchor=CENTER)
        R3.place(relx=0.2,rely=0.4,anchor=CENTER)
        R4.place(relx=0.2,rely=0.5,anchor=CENTER)
        R5.place(relx=0.2,rely=0.6,anchor=CENTER)
        R6.place(relx=0.7,rely=0.2,anchor=CENTER)
        R7.place(relx=0.7,rely=0.3,anchor=CENTER)
        R8.place(relx=0.7,rely=0.4,anchor=CENTER)
        R9.place(relx=0.7,rely=0.5,anchor=CENTER)
        R10.place(relx=0.7,rely=0.6,anchor=CENTER)
        
        
        global cal
        cal=PhotoImage(file="Image/check.png")
        
#         button1.grid(row=10,column = 0)
        button1.place(relx = 0.45, rely = 0.75, anchor = CENTER)
    
        
        

d = login(root)
root.mainloop()
